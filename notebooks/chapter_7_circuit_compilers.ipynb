// %% [markdown]
// # Chapter 7: Circuit Compilers
//
// ## Setup

// %%
:dep mathlib = { git = "https://github.com/Tranduy1dol/mathlib" }
:dep curvelib = { git = "https://github.com/Tranduy1dol/curvelib" }

// %% [markdown]
// ## Summary
//
// ---
// This chapter covers Circuit Compilers, Primitive Types, and Cryptographic Primitives in the context of ZK proofs.

// %% [markdown]
// ### Exercise 103
//
// > Let $F$ be the field $F_5$ of modular 5 arithmetics from example 16. **Brain-compile** the following PAPER statement into an algebraic circuit:
// >
// > ```rust
// > statement STUPID_CIRC {F: F_5} {
// >   fn foo(in_1 : F, in_2 : F)->(out_1 : F, out_2 : F,){
// >     constant c_1 : F = 3 ;
// >     out_1<== ADD( MUL( c_1 , in_1 ) , in_1 ) ;
// >     out_2<== INV( c_1 , in_2 ) ;
// >   } ;
// >   fn main(in_1 : F, in_2 ; F)->(out_1 : F, out_2 : TYPE_2){
// >     constant (c_1,c_2) : (F,F) = (3,2) ;
// >     (out_1,out_2) <== foo(in_1, in_2) ;
// >   } ;
// > }
// > ```
//
// **📝 Note:** TODO: Implement solution
// ---

// %% [markdown]
// ### Exercise 104
//
// > Consider the tiny-jubjub curve from example 71 and its associated circuit 124. **Write a statement in PAPER** that brain-compiles the statement into a circuit equivalent to the one derived in 124, assuming that curve point is the instance and every other assignment is a witness.
//
// **📝 Note:** TODO: Implement solution
// ---

// %% [markdown]
// ### Exercise 105
//
// > Let $F = F_{13}$ be the modular 13 prime field and $x \in F$ some field element. **Define a statement in PAPER** such that given instance $x$ a field element $y \in F$ is a witness for the statement if and only if $y$ is the square root of $x$. **Brain-compile** the statement into a circuit and **derive its associated Rank-1 Constraint System**. Consider the instance $x = 9$ and compute a constructive proof for the statement.
//
// **📝 Note:** TODO: Implement solution
// ---

// %% [markdown]
// ### Exercise 106
//
// > Let $F$ be a finite field and let $b_1$ as well as $b_2$ two boolean constrained variables from $F$. **Show that the equation $OR(b_1, b_2) = 1 - (1 - b_1) \cdot (1 - b_2)$ holds true.** Use this equation to derive an algebraic circuit with ingoing variables $b_1$ and $b_2$ and outgoing variable $OR(b_1, b_2)$ such that $b_1$ and $b_2$ are boolean constrained and the circuit has a valid assignment, if and only if $OR(b_1, b_2) = b_1 \vee b_2$. Use the technique from 6.2.2.4 to transform this circuit into a Rank-1 Constraint System and find its full solution set. **Define a PAPER function** that brain-compiles into the circuit.
//
// **📝 Note:** TODO: Implement solution
// ---

// %% [markdown]
// ### Exercise 107
//
// > Let $F$ be a finite field. **Derive algebraic circuits and associated Rank-1 Constraint Systems** for the following operators: NOR, XOR, NAND, EQU.
//
// **📝 Note:** TODO: Implement solution
// ---

// %% [markdown]
// ### Exercise 108
//
// > Let $F = F_{13}$ and $N = 4$ be fixed and let $x$ be of $uN$ type. **Define circuits and associated R1CS** for the left and right bit-shift operators $x \ll 2$ as well as $x \gg 2$. **Execute the associated circuit** for $x : u4 = 11$ and generate a constructive proof for R1CS satisfiability.
//
// **📝 Note:** TODO: Implement solution
// ---

// %% [markdown]
// ### Exercise 109
//
// > Let $F = F_{13}$ and $N = 2$ be fixed. **Define a circuit and associated R1CS** for the addition operator $ADD : uN \times uN \to uN$. **Execute the associated circuit** to compute $ADD(2, 7)$ for $2, 7 \in uN$.
//
// **📝 Note:** TODO: Implement solution
// ---

// %% [markdown]
// ### Exercise 110
//
// > **Execute the setup phase** for the following PAPER code (That is brain compile the code into a circuit and derive the associated R1CS):
// >
// > ```rust
// > statement MASK_MERGE {F:F_5, N=4} {
// >   fn main(pub a : uN, pub b : uN) -> uN {
// >     let constant mask : uN = 10 ;
// >     let r : uN ;
// >     r <== XOR(a,AND(XOR(a,b),mask)) ;
// >     return r ;
// >   }
// > }
// > ```
// > Let $L_{mask\_merge}$ be the language defined by the circuit. **Provide a constructive knowledge proof** in $L_{mask\_merge}$ for the instance $I = (I_a, I_b) = (14, 7)$.
//
// **📝 Note:** TODO: Implement solution
// ---

// %% [markdown]
// ### Exercise 111
//
// > **Write the circuit and associated Rank-1 Constraint System** for a Weierstrass curve of a given field $F$.
//
// **📝 Note:** TODO: Implement solution
// ---

// %% [markdown]
// ### Exercise 112
//
// > Let $F$ be a field. **Define a circuit** that enforces field inversion for a point of a twisted Edwards curve over $F$.
//
// **📝 Note:** TODO: Implement solution
// ---

// %% [markdown]
// ### Exercise 113
//
// > **Write the circuit and associated Rank-1 Constraint System** for a Weierstrass addition law of a given field $F$.
//
// **📝 Note:** TODO: Implement solution
// ---
